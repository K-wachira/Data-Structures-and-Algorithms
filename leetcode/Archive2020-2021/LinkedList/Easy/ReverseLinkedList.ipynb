# %% [markdown]
# # Reverse Linked List
# [Question Link](https://leetcode.com/problems/reverse-linked-list/)
#
# Reverse a singly linked list.
#
# `Input: 1->2->3->4->5->NULL
#  Output: 5->4->3->2->1->NULL`
#
# while head.next is nothing
# thats the last element and assign it to a variable
# make that variable the next item of our reversed linked list
# remove the variable from the last position of original linked list

# %%
# Definition for singly-linked list.
# class ListNode(object):
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
class Solution(object):
    def reverseList(self, head):
        """
        :type head: ListNode
        :rtype: ListNode
        """
        if not head:
            return head
        
        curr = head        
        while curr.next:
            temp = curr.next
            curr.next = temp.next
            temp.next = head
            head = temp
            
        return head

# %%
class Solution:
    def reverseList(self, head: ListNode) -> ListNode:
        if not head:
            return head
        
        nums = []
        curr = head
        while curr: # Strip the values
            nums.append(curr.val)
            curr = curr.next
            
        nums[:] = nums[::-1]  # Reverse the list
        head = ListNode()    # This  is how we initialize a linkedlist
        curr = head 
        for x in nums:
            curr.next = ListNode(x) # This is how we add numbers on the list
            curr = curr.next
            
        return head.next

# %%
# Definition for singly-linked list.
class ListNode(object):
     def __init__(self, val=0, next=None):
         self.val = val
         self.next = next
            
class Solution(object):
    def reverselist(self, l1):
        curr = l1
        prev = None
        while curr:
            next =  curr.next
            curr.next = prev
            prev = curr
            curr = next
        head = prev
        
        while head:
            print(head.val)
            head = head.next
        
l1 = ListNode(1)
l2 = ListNode(2)        
l3 = ListNode(3)
l4 = ListNode(4)            
l5 = ListNode(5)
l6 = ListNode(6)

Write up the Linked list DataStructure

Final input and the correct output as Answer
l1.next = l2
l2.next = l3
l3.next = l4
l4.next = l5
l5.next = l6
l6.next = None


obj = Solution()
obj.reverselist(l1)
    
    
# Reversing a LinkedList

#Input: 1->2->3->4->5->NULL
#Output: 5->4->3->2->1->NULL`

    
# First create a ListNode class
.Next: create a solution class and code up the correct Algorithms    
    
Initialize the linkedList Datastructure ...Boring 

Glitch


create a Solution class instance 
and call the methods needed   
    
    
    Final output

# %%
#Input: 1->2->3->4->5->6->7->NULL
#Output: 7->6->5->4->3->2->1->NULL`

#First create the ListNode class


# Second Create the Solution class and code up the Algorithms
class ListNode:
    def __init__(self, val = 0, next= None):
        self.val = val
        self.next = next
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
# always keep track of three variables previous, current and next
class Solution():
    def reverse_list(self, head):
        prev = None
        curr= head # So as to not change the Adress of head
        
        while curr:  # while current is not None, means we are not done
            next = curr.next # swap
            curr.next = prev
            prev = curr
            curr = next
        head = prev 
        # set the value of previous(address) which is the last one to head 
        print("\n\n\n\n")
        print("OutPut=\n")
        while head:
            print(str(head.val)+ "->", end = "")
            head = head.next
        print("\n\n\n\n")
            
            
            
            
head = ListNode(1)
l2 = ListNode(2)
l3 = ListNode(3)
l4 = ListNode(4)
l5 = ListNode(5)
l5 = ListNode(6)
l6 = ListNode(7)

head.next = l2
l2.next = l3
l3.next = l4
l4.next = l5
l5.next = l6
l6.next = None




print("\n\n\n\n")
print("Input =\n")
curr = head
while curr:
    print(str(curr.val)+ "->", end = "")
    curr = curr.next







obj = Solution()
obj.reverse_list(head)
# Out:
# Input =
#
# 1->2->3->4->6->7->
#
#
#
#
# OutPut=
#
# 7->6->4->3->2->1->

# %%
import collections

import math
def draw_h_tree(start_coor, length, depth):
  queue = collections.deque([(start_coor, 1 ,length)])
 
  while queue:
    middle, curr_depth ,curr_leng= queue.popleft()
    leng = curr_leng/2
    x, y = middle.x, middle.y
   
    # draw middle
    start = Coordinate(x-leng, y)
    end = Coordinate(x+leng, y)
    drawLine(start, end)
    # append to queue
   
    # draw left
    start = Coordinate( x-leng, y+leng)
    end = Coordinate( x-leng, y-leng)
    drawLine(start, end)
   
    #append to queue
    # draw right
   
    start =Coordinate( x+leng, y+leng)
    end = Coordinate ( x-leng, y-leng)
    drawLine(start, end)
   
    topleft = Coordinate(x-leng, y+leng)
    topright = Coordinate(x+leng, y+leng)
    bottomleft= Coordinate(x-leng, y-leng)
    bottomright = Coordinate(x+leng, y-leng)

    length = curr_leng / math.sqrt(2)
    if curr_depth+1 <= depth:
      queue.append((topleft, curr_depth+1, length ))
      queue.append((topright, curr_depth+1, length))
      queue.append((bottomleft, curr_depth+1, length))
      queue.append((bottomright, curr_depth+1, length))

   

   
class Coordinate:
  def __init__(self, x, y):
    self.x = x
    self.y = y
   
def drawLine(start_coordinate, end_coordinate):
  print(start_coordinate.x, start_coordinate.y, end_coordinate.x, end_coordinate.y)

# %%
import collections 

import math 
def draw_h_tree(center, length, depth):
  # center, depth and leng
  queue = collections.deque( [(center, 1 , length )])
  while queue: 
    
    middle, curr_depth, curr_leng = queue.popleft()
    if curr_depth > depth: break  
      
      
    leng = curr_leng / 2 
    x, y = middle.x, middle.y
    
    # middle 
    start_middle = Co(x- leng, y)
    end_middle = Co(x+ leng, y )
    draw( start_middle, end_middle)
    
    # left 
    start = Co( x-leng, y+leng)
    end = Co(x-leng, y-leng)
    draw( start, end)

    
    # right 
    start = Co( x+ leng, y+ leng)
    end = Co(x-leng, y-leng)
    draw( start, end)
    
    topleft =  Co( x- leng, y + leng)
    topright=  Co( x+leng, y+leng)
    bottomleft = Co( x-leng, y-leng)
    bottomright = Co( x+leng, y-leng)
    legth = curr_leng / math.sqrt(2)
    
    if curr_depth +1 <= depth:
      
      queue.append( ( topleft   ,curr_depth+1 , legth ))
      queue.append( ( topright   ,curr_depth+1 , legth ))
      queue.append( ( bottomleft  , curr_depth+1 , legth ))
      queue.append( ( bottomright  ,curr_depth+1 , legth ))

class Co:
  def __init__(self, x, y):
    self.x = x
    self.y = y 
    

def draw( start, end ):
  print(start.x, end.x, start.y ,end.y)

  
  
  
  
  
draw_h_tree(Co(0,0), 5, 2)
# Out:
# -2.5 2.5 0 0
# -2.5 -2.5 2.5 -2.5
# 2.5 -2.5 2.5 -2.5
# -4.267766952966369 -0.7322330470336313 2.5 2.5
# -4.267766952966369 -4.267766952966369 4.267766952966369 0.7322330470336313
# -0.7322330470336313 -4.267766952966369 4.267766952966369 0.7322330470336313
# 0.7322330470336313 4.267766952966369 2.5 2.5
# 0.7322330470336313 0.7322330470336313 4.267766952966369 0.7322330470336313
# 4.267766952966369 0.7322330470336313 4.267766952966369 0.7322330470336313
# -4.267766952966369 -0.7322330470336313 -2.5 -2.5
# -4.267766952966369 -4.267766952966369 -0.7322330470336313 -4.267766952966369
# -0.7322330470336313 -4.267766952966369 -0.7322330470336313 -4.267766952966369
# 0.7322330470336313 4.267766952966369 -2.5 -2.5
# 0.7322330470336313 0.7322330470336313 -0.7322330470336313 -4.267766952966369
# 4.267766952966369 0.7322330470336313 -0.7322330470336313 -4.267766952966369
