# %%
class TreeNode():
    def __init__(self, val = 0 ,right = None, left=None):
        self.val = val
        self.left = left
        self.right = right
    
    

# class TreeNode():
#     def __init__(self, val = 0, left = None, right= None):
#         self.val = val
#         self.left = left
#         self.right = right

# %%
class BinarySearchTree():
        def __init__(self, root= None):
            self.root = root
            
        def insertion(self, value):
            
            if self.root == None:
                self.root = TreeNode(value)
            else:
                self._insertion(self.root, value)
        def _insertion(self, curr_node, value):
            if value < curr_node.val:
                if curr_node.left == None:
                    curr_node.left = TreeNode(value)
                else:
                    self._insertion(curr_node.left, value)
            elif value > curr_node.val:
                if curr_node.right == None:
                    curr_node.right = TreeNode(value)
                else:
                    self._insertion(curr_node.right, value)
            else:
                print("Value already in tree")
                
                
                
        
        
        
        def printTree(self):
            if self.root== None:
                print("Tree is empty")
            else:
                self._printTree(self.root)

        def _printTree(self, curr_node):
            if curr_node:
                self._printTree(curr_node.left)
                print(curr_node.val)
                self._printTree(curr_node.right)
                
                
                
                
                
        def searchTerm(self, value):
            if self.root == None:
                print("Tree is empty")
            else:
                self._searchTerm(self.root, value)
        def _searchTerm(self, curr_node, value):
            if curr_node:
                if curr_node.val == value:
                    print("Value in tree")
                    return
                elif value < curr_node.val:
                    return self._searchTerm(curr_node.left, value)
                elif value > curr_node.val:
                    return self._searchTerm(curr_node.right, value)
            else: 
                print("Value not found in tree")
                return 
            
            
        def getHeight(self):
            if self.root == None:
                print(0)
                return 
            else:
                print(self._getHeight(self.root, 0))
                
        def _getHeight(self, curr_node, height):
            if curr_node == None:
                return height
            
            else:
                
                left = self._getHeight(curr_node.left, height+1)
                right = self._getHeight(curr_node.right , height+ 1)
                
            return max(left, right)
            



tree = BinarySearchTree()

nums = [1,2,3,4,5,6,7]

tree.insertion(3)
tree.insertion(2)
tree.insertion(1)
tree.insertion(4)
tree.insertion(5)

tree.printTree()

tree.searchTerm(3)
tree.getHeight()
# Out:
# 1
# 2
# 3
# 4
# 5
# Value in tree
# 3
