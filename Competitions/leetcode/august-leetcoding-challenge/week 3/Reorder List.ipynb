# %% [markdown]
# # Reorder List
#
# [Question Link](https://leetcode.com/explore/challenge/card/august-leetcoding-challenge/551/week-3-august-15th-august-21st/3430/)
#
# Given a singly linked list L: L0→L1→…→Ln-1→Ln,
# reorder it to: L0→Ln→L1→Ln-1→L2→Ln-2→…
#
# You may not modify the values in the list's nodes, only nodes itself may be changed.
#
# Example 1:
#
#     Given 1->2->3->4, reorder it to 1->4->2->3.
#
# Example 2:
#
#     Given 1->2->3->4->5, reorder it to 1->5->2->4->3.

# %%
# Definition for singly-linked list.
class ListNode(object):
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

# %%
import math
class Solution(object):
    
    def __init__(self):
        
    
        self.head = None
    def reorderList(self, head):
        self.head = head
        leng = 0
        curr_node = self.head
        
        while curr_node != None:
            leng+=1
            curr_node = curr_node.next
        i = 1
        curr_node = head
        end = int(leng)
        reordered = []
        while curr_node != None and i <= math.ceil(leng/2): 
            reordered.append(curr_node.val)
            back_node = curr_node
            end -=i
            for x in range(leng):
                if x == end:
                    reordered.append(back_node.val)
                elif x < end: 
                    if back_node != None:
                        back_node = back_node.next
            curr_node = curr_node.next
            i+=1
            
        print(reordered)
        
        
        for i in reordered:
            x = self.insertion(i)
        return x
             
    
        
     
    def insertion (self, value):
        if self.head == None:
            self.head = ListNode(value)
        else:
            curr_node = self.head
            
            while curr_node.next != None:
                curr_node = curr_node.next
                
            curr_node.next  = ListNode(value)
        return self.head
            
    def printing(self):
        if self.head == None:
            return "Empty"
        else:
            curr_node = self.head
            while curr_node != None:
                print(curr_node.val, end=' ')
                curr_node = curr_node.next
                
    
    
linked_list = Solution()

for i in range(1,6):
    x =linked_list.insertion(i)
    

linked_list.reorderList(x)
            
 # 1->5->2->4->3.
# Out:
# [1, 5, 2, 4, 3]

# %%
# Definition for singly-linked list.
# class ListNode(object):
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
class Solution:
    def reorderList(self, head) :
        """
        Do not return anything, modify head in-place instead.
        """
        
        if not head:
            return
        
        # Get a list of all nodes
        nodes = []
        while head:
            nodes.append(head)
            head = head.next

        # iterate through list forward and reversed.
        i=0
        j = len(nodes)-1
        while i < j:
           
            tmp = nodes[i].next
            nodes[i].next = nodes[j]
            nodes[j].next = tmp
            # increment/decrement indexes and repeat
            i+=1
            j-=1
        
        # Need to set last node.next = None, this will always be nodes[i]
        nodes[i].next = None
        return

# %%
class Solution(object):
    def reorderList(self, head):
        self.head = head
        leng = 0
        curr_node = self.head
        
        while curr_node != None:
            leng+=1
            curr_node = curr_node.next
        i = 1
        curr_node = head
        end = int(leng)
        reordered = []
        while curr_node != None and i <= math.ceil(leng/2): 
            reordered.append(curr_node.val)
            back_node = curr_node
            end -=i
            for x in range(leng):
                if x == end:
                    reordered.append(back_node.val)
                elif x < end: 
                    if back_node != None:
                        back_node = back_node.next
            curr_node = curr_node.next
            i+=1
            
        print(reordered)
        
        List1 = ListNode(reordered[0])
        reordered.pop(0)
        curr_node = List1
        i = 1
        while reordered:

            curr_node.next= ListNode(reordered[0]) 
            curr_node = curr_node.next
            reordered.pop(0)
          
            
        while  List1 != None:
            print(List1.val)
            List1 = List1.next
